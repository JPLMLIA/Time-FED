# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sktime

# %% [markdown]
# ## Italy Power Demand dataset

# %%
from sktime.datasets import load_italy_power_demand, load_basic_motions
X, y = load_italy_power_demand()

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X.shape
# Out:
# (1096, 1)

# %%
y.shape
# Out:
# (1096,)

# %%
X.columns

# %%
# X.dim_0.str.split(n=3, expand=False)

# %%
type(X.dim_0)

# %%
X.dim_0.loc[1]

# %%
y[y == '1'] = 0
y[y == '2'] = 1

# %%
y = y.astype(int)
y
y[2]

# %% [markdown]
# Convert this to multi-track dataset

# %%
year=1999
for i in X.index:
    if i % 12 == 0:
        year += 1
        print("New year: {}".format(year))
    dtindex = pd.date_range(start=pd.datetime(year, (i % 12) + 1, 1), periods=24, freq='d')
    a = X.dim_0.loc[i].to_frame(name='power')
    a['dtindex'] = dtindex
    a.set_index(keys='dtindex', drop=True, inplace=True)
    a['label'] = y[i]
    a.to_hdf('power.data.label.h5'.format(i), key='/data/{}'.format(i))

# %% [markdown]
# ### Check Saved Power Demand Data

# %%
a  = pd.read_hdf('power.data.label.h5', key='/data/12')

# %%
type(a)

# %%
a.index

# %% [markdown]
# ### Extract has been run.  Now check output.

# %%
a  = pd.HDFStore('power.extract.h5')

# %%
print(a.keys())
a.close()
# Out:
# ['/windows/data/0', '/windows/data/1', '/windows/data/10', '/windows/data/100', '/windows/data/1000', '/windows/data/1001', '/windows/data/1002', '/windows/data/1003', '/windows/data/1004', '/windows/data/1005', '/windows/data/1006', '/windows/data/1007', '/windows/data/1008', '/windows/data/1009', '/windows/data/101', '/windows/data/1010', '/windows/data/1011', '/windows/data/1012', '/windows/data/1013', '/windows/data/1014', '/windows/data/1015', '/windows/data/1016', '/windows/data/1017', '/windows/data/1018', '/windows/data/1019', '/windows/data/102', '/windows/data/1020', '/windows/data/1021', '/windows/data/1022', '/windows/data/1023', '/windows/data/1024', '/windows/data/1025', '/windows/data/1026', '/windows/data/1027', '/windows/data/1028', '/windows/data/1029', '/windows/data/103', '/windows/data/1030', '/windows/data/1031', '/windows/data/1032', '/windows/data/1033', '/windows/data/1034', '/windows/data/1035', '/windows/data/1036', '/windows/data/1037', '/windows/data/1038', '/windows/data/1039', '/windows/data/104', '/windows/data/1040', '/windows/data/1041', '/windows/data/1042', '/windows/data/1043', '/windows/data/1044', '/windows/data/1045', '/windows/data/1046', '/windows/data/1047', '/windows/data/1048', '/windows/data/1049', '/windows/data/105', '/windows/data/1050', '/windows/data/1051', '/windows/data/1052', '/windows/data/1053', '/windows/data/1054', '/windows/data/1055', '/windows/data/1056', '/windows/data/1057', '/windows/data/1058', '/windows/data/1059', '/windows/data/106', '/windows/data/1060', '/windows/data/1061', '/windows/data/1062', '/windows/data/1063', '/windows/data/1064', '/windows/data/1065', '/windows/data/1066', '/windows/data/1067', '/windows/data/1068', '/windows/data/1069', '/windows/data/107', '/windows/data/1070', '/windows/data/1071', '/windows/data/1072', '/windows/data/1073', '/windows/data/1074', '/windows/data/1075', '/windows/data/1076', '/windows/data/1077', '/windows/data/1078', '/windows/data/1079', '/windows/data/108', '/windows/data/1080', '/windows/data/1081', '/windows/data/1082', '/windows/data/1083', '/windows/data/1084', '/windows/data/1085', '/windows/data/1086', '/windows/data/1087', '/windows/data/1088', '/windows/data/1089', '/windows/data/109', '/windows/data/1090', '/windows/data/1091', '/windows/data/1092', '/windows/data/1093', '/windows/data/1094', '/windows/data/1095', '/windows/data/11', '/windows/data/110', '/windows/data/111', '/windows/data/112', '/windows/data/113', '/windows/data/114', '/windows/data/115', '/windows/data/116', '/windows/data/117', '/windows/data/118', '/windows/data/119', '/windows/data/12', '/windows/data/120', '/windows/data/121', '/windows/data/122', '/windows/data/123', '/windows/data/124', '/windows/data/125', '/windows/data/126', '/windows/data/127', '/windows/data/128', '/windows/data/129', '/windows/data/13', '/windows/data/130', '/windows/data/131', '/windows/data/132', '/windows/data/133', '/windows/data/134', '/windows/data/135', '/windows/data/136', '/windows/data/137', '/windows/data/138', '/windows/data/139', '/windows/data/14', '/windows/data/140', '/windows/data/141', '/windows/data/142', '/windows/data/143', '/windows/data/144', '/windows/data/145', '/windows/data/146', '/windows/data/147', '/windows/data/148', '/windows/data/149', '/windows/data/15', '/windows/data/150', '/windows/data/151', '/windows/data/152', '/windows/data/153', '/windows/data/154', '/windows/data/155', '/windows/data/156', '/windows/data/157', '/windows/data/158', '/windows/data/159', '/windows/data/16', '/windows/data/160', '/windows/data/161', '/windows/data/162', '/windows/data/163', '/windows/data/164', '/windows/data/165', '/windows/data/166', '/windows/data/167', '/windows/data/168', '/windows/data/169', '/windows/data/17', '/windows/data/170', '/windows/data/171', '/windows/data/172', '/windows/data/173', '/windows/data/174', '/windows/data/175', '/windows/data/176', '/windows/data/177', '/windows/data/178', '/windows/data/179', '/windows ...

# %%
power_extracted_df = pd.read_hdf('power.extract.h5', '/windows/data/55')

# %%
power_extracted_df.shape
# Out:
# (1, 419)

# %%
# 'label' in power_extracted_df.columns

# %%
power_extracted_stats_df = power_extracted_df.describe()

# %%
power_extracted_stats_df.columns
# Out:
# Index(['power__variance_larger_than_standard_deviation',
#        'power__has_duplicate_max', 'power__has_duplicate_min',
#        'power__has_duplicate', 'power__sum_values', 'power__abs_energy',
#        'power__mean_abs_change', 'power__mean_change',
#        'power__mean_second_derivative_central', 'power__median',
#        ...
#        'power__fourier_entropy__bins_5', 'power__fourier_entropy__bins_10',
#        'power__fourier_entropy__bins_100',
#        'power__permutation_entropy__dimension_3__tau_1',
#        'power__permutation_entropy__dimension_4__tau_1',
#        'power__permutation_entropy__dimension_5__tau_1',
#        'power__permutation_entropy__dimension_6__tau_1',
#        'power__permutation_entropy__dimension_7__tau_1',
#        'power__mean_n_absolute_max__number_of_maxima_7', 'label'],
#       dtype='object', length=419)

# %%
np.sum(power_extracted_stats_df.loc['std'] != 0)
# Out:
# 419

# %%
feats = power_extracted_stats_df.loc['std',power_extracted_stats_df.loc['std'] != 0].index

# %%
feats
# Out:
# Index(['power__variance_larger_than_standard_deviation',
#        'power__has_duplicate_max', 'power__has_duplicate_min',
#        'power__has_duplicate', 'power__sum_values', 'power__abs_energy',
#        'power__mean_abs_change', 'power__mean_change',
#        'power__mean_second_derivative_central', 'power__median',
#        ...
#        'power__fourier_entropy__bins_5', 'power__fourier_entropy__bins_10',
#        'power__fourier_entropy__bins_100',
#        'power__permutation_entropy__dimension_3__tau_1',
#        'power__permutation_entropy__dimension_4__tau_1',
#        'power__permutation_entropy__dimension_5__tau_1',
#        'power__permutation_entropy__dimension_6__tau_1',
#        'power__permutation_entropy__dimension_7__tau_1',
#        'power__mean_n_absolute_max__number_of_maxima_7', 'label'],
#       dtype='object', length=419)

# %%
power_extracted_df_cols_randsamp = power_extracted_df[feats].sample(n=10,axis='columns')

# %%
power_extracted_df_cols_randsamp.index
# Out:
# DatetimeIndex(['2004-08-24'], dtype='datetime64[ns]', freq=None)

# %%
power_extracted_df.index
# Out:
# DatetimeIndex(['2004-08-24'], dtype='datetime64[ns]', freq=None)

# %%
pos_example = np.all(power_extracted_df['label'] == 1)
# Out:
# True

# %%
def print_randsamp_columns(randsamp_cols, df, pos_example):
    
    
    for col in randsamp_cols:
        if pos_example:
            lcolor='g'
        else:
            lcolor='r'
        plt.figure()
        power_extracted_df[col].plot(label=col, color=lcolor)
        plt.legend()
        plt.show()
        
    return

pos_example = np.all(power_extracted_df['label'] == 1)
print_randsamp_columns(power_extracted_df_cols_randsamp.columns, power_extracted_df[feats], pos_example)

# %% [markdown]
# ### Now check how consistently extract features produced the same feature sets

# %%
sets = []
for i in np.arange(0, 100):
    extracted_df = pd.read_hdf('power.extract.h5', '/windows/data/{}'.format(i))
    columns_as_set = set(extracted_df.columns)
    sets.append(columns_as_set)

# %%
a = set.intersection(*sets)
a
# Out:
# {'label',
#  'power__abs_energy',
#  'power__absolute_maximum',
#  'power__absolute_sum_of_changes',
#  'power__agg_autocorrelation__f_agg_"mean"__maxlag_40',
#  'power__agg_autocorrelation__f_agg_"median"__maxlag_40',
#  'power__agg_autocorrelation__f_agg_"var"__maxlag_40',
#  'power__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"',
#  'power__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"mean"',
#  'power__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"',
#  'power__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"',
#  'power__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"max"',
#  'power__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"mean"',
#  'power__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"min"',
#  'power__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"var"',
#  'power__agg_linear_trend__attr_"rvalue"__chunk_len_10__f_agg_"max"',
#  'power__agg_linear_trend__attr_"rvalue"__chunk_len_10__f_agg_"mean"',
#  'power__agg_linear_trend__attr_"rvalue"__chunk_len_10__f_agg_"min"',
#  'power__agg_linear_trend__attr_"rvalue"__chunk_len_10__f_agg_"var"',
#  'power__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"max"',
#  'power__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"mean"',
#  'power__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"min"',
#  'power__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"var"',
#  'power__agg_linear_trend__attr_"slope"__chunk_len_10__f_agg_"max"',
#  'power__agg_linear_trend__attr_"slope"__chunk_len_10__f_agg_"mean"',
#  'power__agg_linear_trend__attr_"slope"__chunk_len_10__f_agg_"min"',
#  'power__agg_linear_trend__attr_"slope"__chunk_len_10__f_agg_"var"',
#  'power__agg_linear_trend__attr_"slope"__chunk_len_5__f_agg_"max"',
#  'power__agg_linear_trend__attr_"slope"__chunk_len_5__f_agg_"mean"',
#  'power__agg_linear_trend__attr_"slope"__chunk_len_5__f_agg_"min"',
#  'power__agg_linear_trend__attr_"slope"__chunk_len_5__f_agg_"var"',
#  'power__agg_linear_trend__attr_"stderr"__chunk_len_10__f_agg_"max"',
#  'power__agg_linear_trend__attr_"stderr"__chunk_len_10__f_agg_"mean"',
#  'power__agg_linear_trend__attr_"stderr"__chunk_len_10__f_agg_"min"',
#  'power__agg_linear_trend__attr_"stderr"__chunk_len_10__f_agg_"var"',
#  'power__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"max"',
#  'power__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"mean"',
#  'power__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"min"',
#  'power__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"var"',
#  'power__approximate_entropy__m_2__r_0.1',
#  'power__approximate_entropy__m_2__r_0.3',
#  'power__approximate_entropy__m_2__r_0.5',
#  'power__approximate_entropy__m_2__r_0.7',
#  'power__approximate_entropy__m_2__r_0.9',
#  'power__ar_coefficient__coeff_0__k_10',
#  'power__ar_coefficient__coeff_10__k_10',
#  'power__ar_coefficient__coeff_1__k_10',
#  'power__ar_coefficient__coeff_2__k_10',
#  'power__ar_coefficient__coeff_3__k_10',
#  'power__ar_coefficient__coeff_4__k_10',
#  'power__ar_coefficient__coeff_5__k_10',
#  'power__ar_coefficient__coeff_6__k_10',
#  'power__ar_coefficient__coeff_7__k_10',
#  'power__ar_coefficient__coeff_8__k_10',
#  'power__ar_coefficient__coeff_9__k_10',
#  'power__augmented_dickey_fuller__attr_"pvalue"__autolag_"AIC"',
#  'power__augmented_dickey_fuller__attr_"teststat"__autolag_"AIC"',
#  'power__augmented_dickey_fuller__attr_"usedlag"__autolag_"AIC"',
#  'power__autocorrelation__lag_0',
#  'power__autocorrelation__lag_1',
#  'power__autocorrelation__lag_2',
#  'power__autocorrelation__lag_3',
#  'power__autocorrelation__lag_4',
#  'power__autocorrelation__lag_5',
#  'power__autocorrelation__lag_6',
#  'power__autocorrelation__lag_7',
#  'power__autocorrelation__lag_8',
#  'power__autocorrelation__lag_9',
#  'power__benford_correlation',
#  'power__binned_entropy__max_bins_10',
#  'power__c3__lag_1',
#  'power__c3__lag_2',
#  'power__c3__lag_3',
#  'power__change_quantiles__f_agg_"mean"__isabs_False__qh_0.2__ql_0.0',
#  'power__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.0',
#  'power__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.2',
#  'power__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.0',
#  'power__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.2',
#  'power__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.4',
#  'power__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.0',
#  'power__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.2',
#  'power__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.4',
#  'power__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.6',
#  'power__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.0',
#  'power__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.2',
#  'power__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.4',
#  'power__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.6',
#  'power__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.8',
#  'power__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.0',
#  'power__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0',
#  'power__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.2',
#  'power__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.0',
#  'power__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.2',
#  'power__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.4',
#  'power__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.0',
#  'power__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2',
#  'power__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.4',
#  'power__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.6',
#  'power__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.0',
#  'power__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.2',
#  'power__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.4',
#  'power__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.6',
#  'power__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.8',
#  'power__change_quantiles__f_agg_"var"__isabs_False__qh_0.2__ql_0.0',
#  'power__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.0',
#  'power__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.2',
#  'power__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.0',
#  'power__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.2',
#  'power__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.4',
#  'power__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.0',
#  'power__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.2',
#  'power__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.4',
#  'power__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.6',
#  'power__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.0',
#  'power__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.2',
#  'power__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.4',
#  'power__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.6',
#  'power__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.8',
#  'power__change_quantiles__f_agg_"var"__isabs_True__qh_0.2__ql_0.0',
#  'power__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.0',
#  'power__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.2',
#  'power__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.0',
#  'power__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.2',
#  'power__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.4',
#  'power__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.0',
#  'power__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.2',
#  'power__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.4',
#  'power__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.6',
#  'power__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.0',
#  'power__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.2',
#  'power__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.4',
#  'power__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.6',
#  'power__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.8',
#  'power__cid_ce__normalize_False',
#  'power__cid_ce__normalize_True',
#  'power__count_above__t_0',
#  'power__count_above_mean',
#  'power__count_below__t_0',
#  'power__count_below_mean',
#  'power__cwt_coefficients__coeff_0__w_10__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_0__w_20__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_0__w_2__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_0__w_5__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_10__w_10__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_10__w_20__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_10__w_2__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_10__w_5__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_11__w_10__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_11__w_20__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_11__w_2__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_11__w_5__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_12__w_10__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_12__w_20__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_12__w_2__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_12__w_5__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_13__w_10__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_13__w_20__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_13__w_2__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_13__w_5__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_14__w_10__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_14__w_20__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_14__w_2__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_14__w_5__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_1__w_10__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_1__w_20__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_1__w_2__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_1__w_5__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_2__w_10__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_2__w_20__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_2__w_2__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_2__w_5__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_3__w_10__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_3__w_20__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_3__w_2__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_3__w_5__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_4__w_10__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_4__w_20__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_4__w_2__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_4__w_5__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_5__w_10__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_5__w_20__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_5__w_2__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_5__w_5__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_6__w_10__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_6__w_20__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_6__w_2__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_6__w_5__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_7__w_10__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_7__w_20__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_7__w_2__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_7__w_5__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_8__w_10__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_8__w_20__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_8__w_2__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_8__w_5__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_9__w_10__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_9__w_20__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_9__w_2__widths_(2, 5, 10, 20)',
#  'power__cwt_coefficients__coeff_9__w_5__widths_(2, 5, 10, 20)',
#  'power__energy_ratio_by_chunks__num_segments_10__segment_focus_0',
#  'power__energy_ratio_by_chunks__num_segments_10__segment_focus_1',
#  'power__energy_ratio_by_chunks__num_segments_10__segment_focus_2',
#  'power__energy_ratio_by_chunks__num_segments_10__segment_focus_3',
#  'power__energy_ratio_by_chunks__num_segments_10__segment_focus_4',
#  'power__energy_ratio_by_chunks__num_segments_10__segment_focus_5',
#  'power__energy_ratio_by_chunks__num_segments_10__segment_focus_6',
#  'power__energy_ratio_by_chunks__num_segments_10__segment_focus_7',
#  'power__energy_ratio_by_chunks__num_segments_10__segment_focus_8',
#  'power__energy_ratio_by_chunks__num_segments_10__segment_focus_9',
#  'power__fft_aggregated__aggtype_"centroid"',
#  'power__fft_aggregated__aggtype_"kurtosis"',
#  'power__fft_aggregated__aggtype_"skew"',
#  'power__fft_aggregated__aggtype_"variance"',
#  'power__fft_coefficient__attr_"abs"__coeff_0',
#  'power__fft_coefficient__attr_"abs"__coeff_1',
#  'power__fft_coefficient__attr_"abs"__coeff_10',
#  'power__fft_coefficient__attr_"abs"__coeff_11',
#  'power__fft_coefficient__attr_"abs"__coeff_12',
#  'power__fft_coefficient__attr_"abs"__coeff_2',
#  'power__fft_coefficient__attr_"abs"__coeff_3',
#  'power__fft_coefficient__attr_"abs"__coeff_4',
#  'power__fft_coefficient__attr_"abs"__coeff_5',
#  'power__fft_coefficient__attr_"abs"__coeff_6',
#  'power__fft_coefficient__attr_"abs"__coeff_7',
#  'power__fft_coefficient__attr_"abs"__coeff_8',
#  'power__fft_coefficient__attr_"abs"__coeff_9',
#  'power__fft_coefficient__attr_"angle"__coeff_0',
#  'power__fft_coefficient__attr_"angle"__coeff_1',
#  'power__fft_coefficient__attr_"angle"__coeff_10',
#  'power__fft_coefficient__attr_"angle"__coeff_11',
#  'power__fft_coefficient__attr_"angle"__coeff_12',
#  'power__fft_coefficient__attr_"angle"__coeff_2',
#  'power__fft_coefficient__attr_"angle"__coeff_3',
#  'power__fft_coefficient__attr_"angle"__coeff_4',
#  'power__fft_coefficient__attr_"angle"__coeff_5',
#  'power__fft_coefficient__attr_"angle"__coeff_6',
#  'power__fft_coefficient__attr_"angle"__coeff_7',
#  'power__fft_coefficient__attr_"angle"__coeff_8',
#  'power__fft_coefficient__attr_"angle"__coeff_9',
#  'power__fft_coefficient__attr_"imag"__coeff_0',
#  'power__fft_coefficient__attr_"imag"__coeff_1',
#  'power__fft_coefficient__attr_"imag"__coeff_10',
#  'power__fft_coefficient__attr_"imag"__coeff_11',
#  'power__fft_coefficient__attr_"imag"__coeff_12',
#  'power__fft_coefficient__attr_"imag"__coeff_2',
#  'power__fft_coefficient__attr_"imag"__coeff_3',
#  'power__fft_coefficient__attr_"imag"__coeff_4',
#  'power__fft_coefficient__attr_"imag"__coeff_5',
#  'power__fft_coefficient__attr_"imag"__coeff_6',
#  'power__fft_coefficient__attr_"imag"__coeff_7',
#  'power__fft_coefficient__attr_"imag"__coeff_8',
#  'power__fft_coefficient__attr_"imag"__coeff_9',
#  'power__fft_coefficient__attr_"real"__coeff_0',
#  'power__fft_coefficient__attr_"real"__coeff_1',
#  'power__fft_coefficient__attr_"real"__coeff_10',
#  'power__fft_coefficient__attr_"real"__coeff_11',
#  'power__fft_coefficient__attr_"real"__coeff_12',
#  'power__fft_coefficient__attr_"real"__coeff_2',
#  'power__fft_coefficient__attr_"real"__coeff_3',
#  'power__fft_coefficient__attr_"real"__coeff_4',
#  'power__fft_coefficient__attr_"real"__coeff_5',
#  'power__fft_coefficient__attr_"real"__coeff_6',
#  'power__fft_coefficient__attr_"real"__coeff_7',
#  'power__fft_coefficient__attr_"real"__coeff_8',
#  'power__fft_coefficient__attr_"real"__coeff_9',
#  'power__first_location_of_maximum',
#  'power__first_location_of_minimum',
#  'power__fourier_entropy__bins_10',
#  'power__fourier_entropy__bins_100',
#  'power__fourier_entropy__bins_2',
#  'power__fourier_entropy__bins_3',
#  'power__fourier_entropy__bins_5',
#  'power__has_duplicate',
#  'power__has_duplicate_max',
#  'power__has_duplicate_min',
#  'power__index_mass_quantile__q_0.1',
#  'power__index_mass_quantile__q_0.2',
#  'power__index_mass_quantile__q_0.3',
#  'power__index_mass_quantile__q_0.4',
#  'power__index_mass_quantile__q_0.6',
#  'power__index_mass_quantile__q_0.7',
#  'power__index_mass_quantile__q_0.8',
#  'power__index_mass_quantile__q_0.9',
#  'power__kurtosis',
#  'power__large_standard_deviation__r_0.05',
#  'power__large_standard_deviation__r_0.1',
#  'power__large_standard_deviation__r_0.15000000000000002',
#  'power__large_standard_deviation__r_0.2',
#  'power__large_standard_deviation__r_0.25',
#  'power__large_standard_deviation__r_0.30000000000000004',
#  'power__large_standard_deviation__r_0.35000000000000003',
#  'power__large_standard_deviation__r_0.4',
#  'power__large_standard_deviation__r_0.45',
#  'power__large_standard_deviation__r_0.5',
#  'power__large_standard_deviation__r_0.55',
#  'power__large_standard_deviation__r_0.6000000000000001',
#  'power__large_standard_deviation__r_0.65',
#  'power__large_standard_deviation__r_0.7000000000000001',
#  'power__large_standard_deviation__r_0.75',
#  'power__large_standard_deviation__r_0.8',
#  'power__large_standard_deviation__r_0.8500000000000001',
#  'power__large_standard_deviation__r_0.9',
#  'power__large_standard_deviation__r_0.9500000000000001',
#  'power__last_location_of_maximum',
#  'power__last_location_of_minimum',
#  'power__lempel_ziv_complexity__bins_10',
#  'power__lempel_ziv_complexity__bins_100',
#  'power__lempel_ziv_complexity__bins_2',
#  'power__lempel_ziv_complexity__bins_3',
#  'power__lempel_ziv_complexity__bins_5',
#  'power__length',
#  'power__linear_trend__attr_"intercept"',
#  'power__linear_trend__attr_"pvalue"',
#  'power__linear_trend__attr_"rvalue"',
#  'power__linear_trend__attr_"slope"',
#  'power__linear_trend__attr_"stderr"',
#  'power__linear_trend_timewise__attr_"intercept"',
#  'power__linear_trend_timewise__attr_"pvalue"',
#  'power__linear_trend_timewise__attr_"rvalue"',
#  'power__linear_trend_timewise__attr_"slope"',
#  'power__linear_trend_timewise__attr_"stderr"',
#  'power__longest_strike_above_mean',
#  'power__longest_strike_below_mean',
#  'power__maximum',
#  'power__mean',
#  'power__mean_abs_change',
#  'power__mean_change',
#  'power__mean_n_absolute_max__number_of_maxima_7',
#  'power__mean_second_derivative_central',
#  'power__median',
#  'power__minimum',
#  'power__number_crossing_m__m_-1',
#  'power__number_crossing_m__m_0',
#  'power__number_crossing_m__m_1',
#  'power__number_cwt_peaks__n_1',
#  'power__number_cwt_peaks__n_5',
#  'power__number_peaks__n_1',
#  'power__number_peaks__n_10',
#  'power__number_peaks__n_3',
#  'power__number_peaks__n_5',
#  'power__number_peaks__n_50',
#  'power__partial_autocorrelation__lag_0',
#  'power__partial_autocorrelation__lag_1',
#  'power__partial_autocorrelation__lag_2',
#  'power__partial_autocorrelation__lag_3',
#  'power__partial_autocorrelation__lag_4',
#  'power__partial_autocorrelation__lag_5',
#  'power__partial_autocorrelation__lag_6',
#  'power__partial_autocorrelation__lag_7',
#  'power__partial_autocorrelation__lag_8',
#  'power__partial_autocorrelation__lag_9',
#  'power__percentage_of_reoccurring_datapoints_to_all_datapoints',
#  'power__percentage_of_reoccurring_values_to_all_values',
#  'power__permutation_entropy__dimension_3__tau_1',
#  'power__permutation_entropy__dimension_4__tau_1',
#  'power__permutation_entropy__dimension_5__tau_1',
#  'power__permutation_entropy__dimension_6__tau_1',
#  'power__permutation_entropy__dimension_7__tau_1',
#  'power__quantile__q_0.1',
#  'power__quantile__q_0.2',
#  'power__quantile__q_0.3',
#  'power__quantile__q_0.4',
#  'power__quantile__q_0.6',
#  'power__quantile__q_0.7',
#  'power__quantile__q_0.8',
#  'power__quantile__q_0.9',
#  'power__range_count__max_0__min_-1000000000000.0',
#  'power__range_count__max_1000000000000.0__min_0',
#  'power__range_count__max_1__min_-1',
#  'power__ratio_beyond_r_sigma__r_0.5',
#  'power__ratio_beyond_r_sigma__r_1',
#  'power__ratio_beyond_r_sigma__r_1.5',
#  'power__ratio_beyond_r_sigma__r_10',
#  'power__ratio_beyond_r_sigma__r_2',
#  'power__ratio_beyond_r_sigma__r_2.5',
#  'power__ratio_beyond_r_sigma__r_3',
#  'power__ratio_beyond_r_sigma__r_5',
#  'power__ratio_beyond_r_sigma__r_6',
#  'power__ratio_beyond_r_sigma__r_7',
#  'power__ratio_value_number_to_time_series_length',
#  'power__root_mean_square',
#  'power__skewness',
#  'power__spkt_welch_density__coeff_2',
#  'power__spkt_welch_density__coeff_5',
#  'power__spkt_welch_density__coeff_8',
#  'power__standard_deviation',
#  'power__sum_of_reoccurring_data_points',
#  'power__sum_of_reoccurring_values',
#  'power__sum_values',
#  'power__symmetry_looking__r_0.0',
#  'power__symmetry_looking__r_0.05',
#  'power__symmetry_looking__r_0.1',
#  'power__symmetry_looking__r_0.15000000000000002',
#  'power__symmetry_looking__r_0.2',
#  'power__symmetry_looking__r_0.25',
#  'power__symmetry_looking__r_0.30000000000000004',
#  'power__symmetry_looking__r_0.35000000000000003',
#  'power__symmetry_looking__r_0.4',
#  'power__symmetry_looking__r_0.45',
#  'power__symmetry_looking__r_0.5',
#  'power__symmetry_looking__r_0.55',
#  'power__symmetry_looking__r_0.6000000000000001',
#  'power__symmetry_looking__r_0.65',
#  'power__symmetry_looking__r_0.7000000000000001',
#  'power__symmetry_looking__r_0.75',
#  'power__symmetry_looking__r_0.8',
#  'power__symmetry_looking__r_0.8500000000000001',
#  'power__symmetry_looking__r_0.9',
#  'power__symmetry_looking__r_0.9500000000000001',
#  'power__time_reversal_asymmetry_statistic__lag_1',
#  'power__time_reversal_asymmetry_statistic__lag_2',
#  'power__time_reversal_asymmetry_statistic__lag_3',
#  'power__value_count__value_-1',
#  'power__value_count__value_0',
#  'power__value_count__value_1',
#  'power__variance',
#  'power__variance_larger_than_standard_deviation'}

# %%
len(a)
# Out:
# 417

# %% [markdown]
# ## Check out sub-select

# %%
power_subselect_train_df = pd.read_hdf('power.subselect.h5', '/select/train')
power_subselect_train_df.shape
# Out:
# (765, 264)

# %%
power_subselect_test_df = pd.read_hdf('power.subselect.h5', '/select/test')
power_subselect_test_df.shape
# Out:
# (331, 264)

# %%
power_subselect_test_df.columns
power_subselect_test_df.index
# Out:
# DatetimeIndex(['2083-05-24', '2083-06-24', '2083-07-24', '2083-08-24',
#                '2083-09-24', '2083-10-24', '2083-11-24', '2083-12-24',
#                '2084-01-24', '2084-02-24',
#                ...
#                '2082-07-24', '2082-08-24', '2082-09-24', '2082-10-24',
#                '2082-11-24', '2082-12-24', '2083-01-24', '2083-02-24',
#                '2083-03-24', '2083-04-24'],
#               dtype='datetime64[ns]', name='index', length=331, freq=None)

# %%
power_subselect_test_df_cols_randsamp = power_subselect_test_df.sample(n=10,axis='columns')

for col in power_subselect_test_df_cols_randsamp.columns:
    if pos_example:
        lcolor='g'
    else:
        lcolor='r'
    plt.figure()
    power_subselect_test_df[col].plot(label=col, color=lcolor)
    plt.legend()
    plt.show()

# %%
power_subselect_train_df_cols_randsamp = power_subselect_train_df.sample(n=10,axis='columns')

# %%
for col in power_subselect_train_df_cols_randsamp.columns:
    if pos_example:
        lcolor='g'
    else:
        lcolor='r'
    plt.figure()
    power_subselect_train_df[col].plot(label=col, color=lcolor)
    plt.legend()
    plt.show()

# %%
power_subselect_train_df.index
# Out:
# DatetimeIndex(['2000-01-24', '2000-02-24', '2000-11-24', '2008-05-24',
#                '2008-06-24', '2008-07-24', '2008-08-24', '2008-09-24',
#                '2008-10-24', '2008-11-24',
#                ...
#                '2007-07-24', '2007-08-24', '2007-09-24', '2007-10-24',
#                '2007-11-24', '2007-12-24', '2008-01-24', '2008-02-24',
#                '2008-03-24', '2008-04-24'],
#               dtype='datetime64[ns]', name='index', length=765, freq=None)

# %%
power_subselect_test_df.index
# Out:
# DatetimeIndex(['2083-05-24', '2083-06-24', '2083-07-24', '2083-08-24',
#                '2083-09-24', '2083-10-24', '2083-11-24', '2083-12-24',
#                '2084-01-24', '2084-02-24',
#                ...
#                '2082-07-24', '2082-08-24', '2082-09-24', '2082-10-24',
#                '2082-11-24', '2082-12-24', '2083-01-24', '2083-02-24',
#                '2083-03-24', '2083-04-24'],
#               dtype='datetime64[ns]', name='index', length=331, freq=None)

# %%
power_subselect_train_df.shape
# Out:
# (765, 264)

# %%
power_subselect_test_df.shape
# Out:
# (331, 264)
